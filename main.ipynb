# %%
# %pip install pdfquery pdfminer.six
# Out:
# Requirement already satisfied: pdfquery in /opt/homebrew/lib/python3.11/site-packages (0.4.3)
# Requirement already satisfied: pdfminer.six in /opt/homebrew/lib/python3.11/site-packages (20221105)
# Requirement already satisfied: cssselect>=0.7.1 in /opt/homebrew/lib/python3.11/site-packages (from pdfquery) (1.2.0)
# Requirement already satisfied: chardet in /opt/homebrew/lib/python3.11/site-packages (from pdfquery) (5.2.0)
# Requirement already satisfied: lxml>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfquery) (5.0.0)
# Requirement already satisfied: pyquery>=1.2.2 in /opt/homebrew/lib/python3.11/site-packages (from pdfquery) (2.0.0)
# Requirement already satisfied: roman>=1.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfquery) (4.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six) (1.16.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
from pdfminer.high_level import extract_pages, extract_text

# %%
i = 0
for page_layout in extract_pages('bills.pdf'):
    for element in page_layout:
        # text = extract_text(element)

        if i == 3:
            print(element)
    if i == 3:
        break
    i += 1
# Out:
# <LTTextBoxHorizontal(0) 32.932,676.021,90.467,685.626 'Small World\n'>
# <LTTextBoxHorizontal(1) 32.932,658.099,51.616,665.646 'From\n'>
# <LTTextBoxHorizontal(2) 32.932,635.826,141.236,646.803 'DELHIVERY LIMITED \n'>
# <LTTextBoxHorizontal(3) 32.932,621.051,119.968,628.598 'I FLOOR, 82, SECTOR-44 \n'>
# <LTTextBoxHorizontal(4) 32.932,606.643,104.188,614.190 'Gurgaon, HARYANA \n'>
# <LTTextBoxHorizontal(5) 32.932,592.235,149.469,599.782 'Pin code: 122002, State Code: 06 \n'>
# <LTTextBoxHorizontal(6) 32.932,577.827,127.515,585.374 'GSTIN : 06AAPCS9575E1ZR \n'>
# <LTTextBoxHorizontal(7) 180.570,687.414,324.128,707.310 '  TAX INVOICE\n'>
# <LTTextBoxHorizontal(8) 314.228,658.099,335.939,665.646 'Bill To\n'>
# <LTTextBoxHorizontal(9) 314.228,635.826,414.299,646.803 'GLOBAL , GLOBAL \n'>
# <LTTextBoxHorizontal(10) 314.228,610.759,390.286,628.598 'faridabad\nFaridabad, HARYANA \n'>
# <LTTextBoxHorizontal(11) 314.228,596.351,430.765,603.898 'Pin code: 121005, State Code: 06 \n'>
# <LTTextBoxHorizontal(12) 314.228,581.944,405.380,589.491 'GSTIN : 06AEYPR6542L2ZJ \n'>
# <LTTextBoxHorizontal(13) 314.228,567.536,347.749,575.083 'PAN : NA \n'>
# <LTTextBoxHorizontal(14) 32.932,531.173,89.780,538.720 'Place of Supply \n'>
# <LTTextBoxHorizontal(15) 109.774,531.173,181.715,538.720 'MADHYA PRADESH \n'>
# <LTTextBoxHorizontal(16) 279.924,531.173,306.437,538.720 'Ship To\n'>
# <LTTextBoxHorizontal(17) 32.932,514.021,74.686,521.568 'Invoice No. \n'>
# <LTTextBoxHorizontal(18) 109.774,514.021,176.913,521.568 'FODE23234132082 \n'>
# <LTTextBoxHorizontal(19) 32.932,496.869,78.802,504.416 'Invoice Date \n'>
# <LTTextBoxHorizontal(20) 109.774,496.869,159.075,504.416 '12-MAY-2023 \n'>
# <LTTextBoxHorizontal(21) 32.932,479.716,48.614,487.263 'SAC \n'>
# <LTTextBoxHorizontal(22) 32.932,462.564,45.483,470.111 'IRN\n'>
# <LTTextBoxHorizontal(23) 109.774,479.716,128.201,487.263 '9965 \n'>
# <LTTextBoxHorizontal(24) 109.774,441.982,233.461,470.111 '91abda997273e9b22590932455d9\nb84b34cf4cdb09515bd397d301cb1\n142e336\n'>
# <LTTextBoxHorizontal(25) 279.924,506.474,465.174,524.312 'TUBA CONSTRUCTIONS AND ELECTRICALS, TUBA C\nONSTRUCTIONS AND ELECTRICALS\n'>
# <LTTextBoxHorizontal(26) 279.924,471.483,463.801,499.613 'VILLAGE SIGORA, NEAR MASJID POST MOTIJHEEL , G\nWALIOR MADHYA PRADESH\nGwalior, MADHYA PRADESH \n'>
# <LTTextBoxHorizontal(27) 279.924,457.076,394.699,464.623 'Pin code: 474010, State Code: 23\n'>
# <LTTextBoxHorizontal(28) 37.735,414.538,81.116,422.085 'Description\n'>
# <LTTextBoxHorizontal(29) 37.735,365.826,115.165,404.247 'Base Freight Charge \nBase Charge: \nProcessing Charge: \nFuel Charges:\n'>
# <LTTextBoxHorizontal(30) 37.735,347.988,95.460,355.535 'Insurance ROV:\n'>
# <LTTextBoxHorizontal(31) 37.735,330.149,129.764,337.696 'Other Handling Charges:\n'>
# <LTTextBoxHorizontal(32) 37.735,312.311,102.321,319.858 'Taxable Amount:\n'>
# <LTTextBoxHorizontal(33) 37.735,294.473,132.365,302.020 'Minimum Charged Freight:\n'>
# <LTTextBoxHorizontal(34) 37.735,276.634,58.268,284.181 'CGST:\n'>
# <LTTextBoxHorizontal(35) 37.735,258.796,57.581,266.343 'SGST:\n'>
# <LTTextBoxHorizontal(36) 257.969,414.538,277.500,422.085 'Units\n'>
# <LTTextBoxHorizontal(37) 331.380,414.538,391.602,422.085 'Invoice Amount\n'>
# <LTTextBoxHorizontal(38) 257.969,365.826,294.234,393.955 '9.5/Kg \n100.00/LR \n20%\n'>
# <LTTextBoxHorizontal(39) 257.969,347.988,274.473,355.535 '0.1%\n'>
# <LTTextBoxHorizontal(40) 257.969,294.473,292.136,302.020 '300.00/LR\n'>
# <LTTextBoxHorizontal(41) 257.969,276.634,278.590,284.181 '6.00%\n'>
# <LTTextBoxHorizontal(42) 257.969,258.796,278.590,266.343 '6.00%\n'>
# <LTTextBoxHorizontal(43) 331.380,381.606,366.570,389.153 'Rs. 499.00\n'>
# <LTTextBoxHorizontal(44) 331.380,347.988,366.570,355.535 'Rs. 100.00\n'>
# <LTTextBoxHorizontal(45) 331.380,330.149,366.570,337.696 'Rs. 183.25\n'>
# <LTTextBoxHorizontal(46) 331.380,312.311,366.562,319.858 'Rs. 782.25\n'>
# <LTTextBoxHorizontal(47) 331.380,276.634,362.453,284.181 'Rs. 46.94\n'>
# <LTTextBoxHorizontal(48) 331.380,258.796,362.453,266.343 'Rs. 46.94\n'>
# <LTTextBoxHorizontal(49) 331.380,240.958,366.562,248.505 'Rs. 876.12\n'>
# <LTTextBoxHorizontal(50) 37.735,240.958,250.954,248.505 'Description of charges: As per agreed terms, \xa0 Total Amount\n'>
# <LTTextBoxHorizontal(51) 43.910,216.945,284.413,224.492 'In words | Eight hundred seventy-six Rupees and twelve Paisa only\n'>
# <LTTextBoxHorizontal(52) 32.932,188.011,117.250,198.302 'Terms and Conditions \n'>
# <LTTextBoxHorizontal(53) 32.932,171.545,405.407,181.836 '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited. \n'>
# <LTTextBoxHorizontal(54) 32.932,155.079,372.475,165.370 '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date. \n'>
# <LTTextBoxHorizontal(55) 32.932,138.613,396.488,148.904 '3. All disputes and diﬀerences arising out of this will be subject to jurisdiction of Gurgaon courts only. \n'>
# <LTTextBoxHorizontal(56) 115.402,103.054,190.088,110.601 'DELHIVERY LIMITED \n'>
# <LTTextBoxHorizontal(57) 115.402,79.041,573.500,96.879 'Registered Oﬃce: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,\nIndia\n'>
# <LTTextBoxHorizontal(58) 115.402,65.319,382.879,72.866 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com \n'>
# <LTTextBoxHorizontal(59) 115.402,51.598,410.501,59.145 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E\n'>
# <LTTextBoxHorizontal(60) 269.976,4.258,569.890,11.805 'This is a system generated invoice. It does not require additional authorization.\n'>
# <LTRect 0.000,0.294,577.000,720.000>
# <LTRect 5.489,562.200,626.398,563.572>
# <LTRect 32.932,433.901,279.924,435.274>
# <LTRect 94.680,455.856,96.052,541.617>
# <LTRect 279.924,433.901,465.168,435.274>
# <LTRect 34.304,410.574,254.539,411.260>
# <LTRect 254.539,410.574,327.950,411.260>
# <LTRect 327.950,410.574,401.361,411.260>
# <LTRect 34.304,361.862,254.539,362.548>
# <LTRect 254.539,361.862,327.950,362.548>
# <LTRect 327.950,361.862,401.361,362.548>
# <LTRect 34.304,344.024,254.539,344.710>
# <LTRect 254.539,344.024,327.950,344.710>
# <LTRect 327.950,344.024,401.361,344.710>
# <LTRect 34.304,326.186,254.539,326.872>
# <LTRect 254.539,326.186,327.950,326.872>
# <LTRect 327.950,326.186,401.361,326.872>
# <LTRect 34.304,308.347,254.539,309.033>
# <LTRect 254.539,308.347,327.950,309.033>
# <LTRect 327.950,308.347,401.361,309.033>
# <LTRect 34.304,290.509,254.539,291.195>
# <LTRect 254.539,290.509,327.950,291.195>
# <LTRect 34.304,272.671,254.539,273.357>
# <LTRect 254.539,272.671,327.950,273.357>
# <LTRect 327.950,272.671,401.361,273.357>
# <LTRect 34.304,254.832,254.539,255.518>
# <LTRect 254.539,254.832,327.950,255.518>
# <LTRect 327.950,254.832,401.361,255.518>
# <LTRect 34.304,236.994,254.539,237.680>
# <LTRect 254.539,236.994,327.950,237.680>
# <LTRect 327.950,236.994,401.361,237.680>
# <LTCurve 33.275,209.208,535.492,235.279>
# <LTRect 5.489,121.045,570.825,122.417>
# <LTFigure(X7) 5.489,52.436,127.612,121.045 matrix=[122.12,0.00,0.00,68.61, (5.49,52.44)]>
# <LTFigure(X9) 32.932,691.184,180.441,714.511 matrix=[147.51,0.00,0.00,23.33, (32.93,691.18)]>
# <LTRect 189.703,694.272,190.389,711.424>
# <LTFigure(X11) 496.042,613.656,571.511,689.126 matrix=[75.47,0.00,0.00,75.47, (496.04,613.66)]>

# %%
from pdfquery import PDFQuery

pdf = PDFQuery('bills.pdf')
pdf.load()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 4
#       1 from pdfquery import PDFQuery
#       3 pdf = PDFQuery('bills.pdf')
# ----> 4 pdf.load()
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:385, in PDFQuery.load(self, *page_numbers)
#     367 def load(self, *page_numbers):
#     368     """
#     369     Load etree and pyquery object for entire document, or given page
#     370     numbers (ints or lists). After this is called, objects are
#    (...)
#     383     [<LTPage>, <LTPage>]
#     384     """
# --> 385     self.tree = self.get_tree(*_flatten(page_numbers))
#     386     self.pq = self.get_pyquery(self.tree)
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:488, in PDFQuery.get_tree(self, *page_numbers)
#     486     pages = enumerate(self.get_layouts())
#     487 for n, page in pages:
# --> 488     page = self._xmlize(page)
#     489     page.set('page_index', obj_to_string(n))
#     490     page.set('page_label', self.doc.get_page_number(n))
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:553, in PDFQuery._xmlize(self, node, root)
#     551 last = None
#     552 for child in node:
# --> 553     child = self._xmlize(child, root)
#     554     if self.merge_tags and child.tag in self.merge_tags:
#     555         if branch.text and child.text in branch.text:
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:553, in PDFQuery._xmlize(self, node, root)
#     551 last = None
#     552 for child in node:
# --> 553     child = self._xmlize(child, root)
#     554     if self.merge_tags and child.tag in self.merge_tags:
#     555         if branch.text and child.text in branch.text:
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:553, in PDFQuery._xmlize(self, node, root)
#     551 last = None
#     552 for child in node:
# --> 553     child = self._xmlize(child, root)
#     554     if self.merge_tags and child.tag in self.merge_tags:
#     555         if branch.text and child.text in branch.text:
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:521, in PDFQuery._xmlize(self, node, root)
#     518     branch = node
#     519 else:
#     520     # collect attributes of current node
# --> 521     tags = self._getattrs(
#     522         node, 'y0', 'y1', 'x0', 'x1', 'width', 'height', 'bbox',
#     523         'linewidth', 'pts', 'index', 'name', 'matrix', 'word_margin'
#     524     )
#     525     if type(node) == LTImage:
#     526         tags.update(self._getattrs(
#     527             node, 'colorspace', 'bits', 'imagemask', 'srcsize',
#     528             'stream', 'name', 'pts', 'linewidth')
#     529         )
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:579, in PDFQuery._getattrs(self, obj, *attrs)
#     577 for attr in attrs:
#     578     if hasattr(obj, attr):
# --> 579         filtered_attrs[attr] = obj_to_string(
#     580             self._filter_value(getattr(obj, attr))
#     581         )
#     582 return filtered_attrs
#
# File /opt/homebrew/lib/python3.11/site-packages/pdfquery/pdfquery.py:174, in obj_to_string(obj, top)
#     172 if type(obj) == six.text_type:
#     173     return obj
# --> 174 return json.dumps(obj)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:249, in JSONEncoder.iterencode(self, o, _one_shot)
#     244     return text
#     247 if (_one_shot and c_make_encoder is not None
#     248         and self.indent is None):
# --> 249     _iterencode = c_make_encoder(
#     250         markers, self.default, _encoder, self.indent,
#     251         self.key_separator, self.item_separator, self.sort_keys,
#     252         self.skipkeys, self.allow_nan)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
#
# KeyboardInterrupt:

# %%
invoices = pdf.pq('LTTextBoxHorizontal:in_bbox("109.774,496.869,159.075,504.416")').text()

len(invoices.split(' '))
# Out:
# 55

# %%
# %pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.10.3-py3-none-any.whl.metadata (38 kB)
# Collecting pdfminer.six==20221105 (from pdfplumber)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 23.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pillow>=9.1 in /opt/homebrew/lib/python3.11/site-packages (from pdfplumber) (10.1.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.25.0-py3-none-macosx_11_0_arm64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Downloading pdfplumber-0.10.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 4.8 MB/s eta 0:00:00
# Downloading pypdfium2-4.25.0-py3-none-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 28.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20231228
#     Uninstalling pdfminer.six-20231228:
#       Successfully uninstalled pdfminer.six-20231228
# Successfully installed pdfminer.six-20221105 pdfplumber-0.10.3 pypdfium2-4.25.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber
import pandas as pd

# %%
i = 0
df = pd.DataFrame(columns=['Place of Supply', 'Invoice No.', 'Invoice Date', 'Markup Amount', 'Taxable Amount', 'IGST', 'CGST','SGST','Total Amount', 'Bill To'])

with pdfplumber.open('bills.pdf') as pdf:
    pages = pdf.pages
    for page in pages:
        text = page.extract_text()
        elements = text.split('\n')
        print(elements)
        place = ''
        invoice_no = ''
        invoice_date = ''
        markup = ''
        taxable_amount = ''
        igst = ''
        cgst = ''
        sgst = ''
        total_amount = ''
        bill_to = ''
        for element in elements:
            if element.startswith('Place of Supply'):
                print(' '.join(element.split(' ')[3:-2]))
                place = ' '.join(element.split(' ')[3:-2])
            if element.startswith('Invoice No.'):
                print(element.split(' ')[2])    
                invoice_no = element.split(' ')[2]
            if element.startswith('Invoice Date'):
                print(element.split(' ')[-1])    
                invoice_date = element.split(' ')[-1]    
            if element.startswith('Markup:'):
                print(element.split(' ')[-1])    
                markup = element.split(' ')[-1]
            if element.startswith('Taxable Amount:'):
                print(element.split(' ')[-1])    
                taxable_amount = element.split(' ')[-1]
            if element.startswith('IGST:'):
                print(element.split(' ')[-1])    
                igst = element.split(' ')[-1]    
            if element.startswith('CGST:'):
                print(element.split(' ')[-1])    
                cgst = element.split(' ')[-1]    
            if element.startswith('SGST:'):
                print(element.split(' ')[-1])    
                sgst = element.split(' ')[-1]    
            if element.startswith('Description of charges: As per agreed terms, Total Amount'):
                print(element.split(' ')[-1])
                total_amount = element.split(' ')[-1]    
        try:
            x = elements.index('From Bill To')
            x += 1
            bill_to = elements[x].split(' , ')[-1]
            print(bill_to)
        except:
            print('error')
        finally:
            pass
        # break
        row = [place, invoice_no, invoice_date, markup, taxable_amount, igst, cgst, sgst,total_amount, bill_to]
        if row != [''] * 10:
            df.loc[len(df)] = row
df.to_csv('bills.csv')
# df.to_excel('bills_excel.xlsx')
# Out:
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply ANDHRA PRADESH Ship To', 'Invoice No. FODD23241417566 INDISO TRENDS LLP,HARI GAARU', 'INDISO TRENDS, CMR CENTRAL PARKING AREA , MA', 'Invoice Date 18-APR-2023', 'DDILAPALEM , VISAKHAPATNAM-530013', 'SAC 9965 Visakhapatnam, ANDHRA PRADESH', 'Pin code: 530013, State Code: 37', 'IRN 63a867b43d99f11e3ac273136c182', 'c5b31f17e9a65a867d953716f3349', '591c38', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 10.5/Kg', 'Rs. 778.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 206.50', 'Markup: Rs. 750.00', 'Taxable Amount: Rs. 1734.50', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 208.14', 'Description of charges: As per agreed terms, Total Amount Rs. 1942.64', 'In words | One thousand, nine hundred forty-two Rupees and sixty-four Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# ANDHRA PRADESH
# FODD23241417566
# 18-APR-2023
# 750.00
# 1734.50
# 208.14
# 1942.64
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply TAMILNADU Ship To', 'Invoice No. FODD23241572826 RAM DAYAL,S/O JEEWAN RAM', '17 ROBINSON NAGAR MADANAKUPPAM KOLATHUR', 'Invoice Date 29-APR-2023', 'TIRU VALLUR TAMIL NADU 600099', 'SAC 9965 Chennai, TAMILNADU', 'Pin code: 600099, State Code: 33', 'IRN d426d8d1d0539a943951195db8b5', '41a004f71f21802bd5baa31bbfafc', '4cd2987', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 5457.11', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 596.43', 'Markup: Rs. 5500.00', 'Taxable Amount: Rs. 11553.54', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 1386.42', 'Description of charges: As per agreed terms, Total Amount Rs. 12939.96', 'In words | Twelve thousand, nine hundred thirty-nine Rupees and ninety-six Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# TAMILNADU
# FODD23241572826
# 29-APR-2023
# 5500.00
# 11553.54
# 1386.42
# 12939.96
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'GROUND FLOOR, PEB GODOWN, BUILDING NO B 2, GALA NO.13, AN faridabad', 'TARIKSH LOGIDROME, VILLAGE SAPE Faridabad, HARYANA', 'Thane, MAHARASHTRA Pin code: 121005, State Code: 06', 'Pin code: 421101, State Code: 27 GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 27AAPCS9575E1ZN PAN : NA', 'Place of Supply HARYANA Ship To', 'Invoice No. FODD23241582323 SAMIKSHA DUDEJA,D/O SAVITA KANWAL DUDEJA', 'F- 152, SECTOR-10, DLF FARIDABAD, HARYANA-1210', 'Invoice Date 28-APR-2023', '06', 'SAC 9965 Faridabad, HARYANA', 'Pin code: 121006, State Code: 06', 'IRN 0d80a7c709c14ff1fd46739ccc0016', 'd2b51567b129833783ddf39c53d99', 'a509f', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 1476.47', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 264.71', 'Taxable Amount: Rs. 1741.18', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 208.94', 'Description of charges: As per agreed terms, Total Amount Rs. 1950.12', 'In words | One thousand, nine hundred fifty Rupees and twelve Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# HARYANA
# FODD23241582323
# 28-APR-2023
# 1741.18
# 208.94
# 1950.12
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'I FLOOR, 82, SECTOR-44 faridabad', 'Faridabad, HARYANA', 'Gurgaon, HARYANA', 'Pin code: 121005, State Code: 06', 'Pin code: 122002, State Code: 06', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 06AAPCS9575E1ZR', 'PAN : NA', 'Place of Supply MADHYA PRADESH Ship To', 'Invoice No. FODE23234132082 TUBA CONSTRUCTIONS AND ELECTRICALS, TUBA C', 'ONSTRUCTIONS AND ELECTRICALS', 'Invoice Date 12-MAY-2023', 'VILLAGE SIGORA, NEAR MASJID POST MOTIJHEEL , G', 'SAC 9965 WALIOR MADHYA PRADESH', 'Gwalior, MADHYA PRADESH', 'IRN 91abda997273e9b22590932455d9', 'Pin code: 474010, State Code: 23', 'b84b34cf4cdb09515bd397d301cb1', '142e336', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 499.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.1% Rs. 100.00', 'Other Handling Charges: Rs. 183.25', 'Taxable Amount: Rs. 782.25', 'Minimum Charged Freight: 300.00/LR', 'CGST: 6.00% Rs. 46.94', 'SGST: 6.00% Rs. 46.94', 'Description of charges: As per agreed terms, Total Amount Rs. 876.12', 'In words | Eight hundred seventy-six Rupees and twelve Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# MADHYA PRADESH
# FODE23234132082
# 12-MAY-2023
# 782.25
# 46.94
# 46.94
# 876.12
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply ASSAM Ship To', 'Invoice No. FODE23241587282 RAJESH DAS,C/O RAJESH DAS', '99 RAJ STORE SANTIPARA DIBRUGARH WEST DIBRU', 'Invoice Date 03-MAY-2023', 'GARH', 'SAC 9965 Dibrugarh, ASSAM', 'Pin code: 786006, State Code: 18', 'IRN b922ec27fa761280e596ace564a7a', '29a63ee0840441003e8ad78c3d7d', '595052f', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 22/Kg', 'Rs. 1161.28', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 313.44', 'Markup: Rs. 500.00', 'Taxable Amount: Rs. 1974.72', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 236.97', 'Description of charges: As per agreed terms, Total Amount Rs. 2211.69', 'In words | Two thousand, two hundred eleven Rupees and sixty-nine Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# ASSAM
# FODE23241587282
# 03-MAY-2023
# 500.00
# 1974.72
# 236.97
# 2211.69
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply WEST BENGAL Ship To', 'Invoice No. FODE23241607916 PAPPU YADAV,S/O PAPPU YADAV', 'UDHAM SINGH SARANI ASHRAM PARA, WARD NO-1', 'Invoice Date 02-MAY-2023', '3 SILIGURI, DARJEELING W.B -734001 PH -926464505', 'SAC 9965 4', 'Siliguri, WEST BENGAL', 'IRN ddbe29dd43a8e0f3eba2e66da8d', 'Pin code: 734001, State Code: 19', '78f2ca6b825ab03323635500132e7', 'ed959110', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 11.5/Kg', 'Rs. 1345.11', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 253.76', 'Markup: Rs. 1950.00', 'Taxable Amount: Rs. 3548.87', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 425.86', 'Description of charges: As per agreed terms, Total Amount Rs. 3974.73', 'In words | Three thousand, nine hundred seventy-four Rupees and seventy-three Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# WEST BENGAL
# FODE23241607916
# 02-MAY-2023
# 1950.00
# 3548.87
# 425.86
# 3974.73
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply CHHATISHGARH Ship To', 'Invoice No. FODE23241629299 CHATTISGARH AUTO ENGINEERING,DEVENDER RA', 'JPURIYA', 'Invoice Date 02-MAY-2023', 'MEAR GUJRATI SAMAJ, BANIYA PARA, ITWARI BAZAR,', 'SAC 9965 DHAMTARI, CHATTISGARH, PIN 493773 PH=90398438', '98', 'IRN f0eab0a6dceb16b2e73a06dcb6cb Dhamtari, CHHATISHGARH', '6a6e6ac1117443ad19571d4ddeaf', 'Pin code: 493773, State Code: 22', '97e1b54e', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 328.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.1% Rs. 100.00', 'ODA Charges: 4/Kg Rs. 750.00', 'Other Handling Charges: Rs. 244.00', 'Markup: Rs. 350.00', 'Taxable Amount: Rs. 1772.00', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 212.64', 'Description of charges: As per agreed terms, Total Amount Rs. 1984.64', 'In words | One thousand, nine hundred eighty-four Rupees and sixty-four Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E']
# CHHATISHGARH
# FODE23241629299
# 02-MAY-2023
# 350.00
# 1772.00
# 212.64
# 1984.64
# GLOBAL
# ['This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply MADHYA PRADESH Ship To', 'Invoice No. FODE23241637656 SNS INFRACON PVT LTD,RAKESH', 'RLBCAU, VETERINARY COLLEGE, VILL NAUNER, DIST.', 'Invoice Date 01-MAY-2023', 'DATIA. MP-475661 PH- 9818162836', 'SAC 9965 Datia, MADHYA PRADESH', 'Pin code: 475661, State Code: 23', 'IRN a6de30004aaf5f0c677b56d005b66', '01f675cfa5135e50da142d60b21aa', '632204', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 969.82', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'ODA Charges: 4/Kg Rs. 750.00', 'Other Handling Charges: Rs. 297.49', 'Markup: Rs. 300.00', 'Taxable Amount: Rs. 2317.31', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 278.08', 'Description of charges: As per agreed terms, Total Amount Rs. 2595.39', 'In words | Two thousand, five hundred ninety-five Rupees and thirty-nine Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# MADHYA PRADESH
# FODE23241637656
# 01-MAY-2023
# 300.00
# 2317.31
# 278.08
# 2595.39
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply ANDHRA PRADESH Ship To', 'Invoice No. FODE23241718034 INDISO TRENDS LLP,HARI GAARU', 'INDISO TRENDS, CMR CENTRAL PARKING AREA , MA', 'Invoice Date 09-MAY-2023', 'DDILAPALEM , VISAKHAPATNAM-530013', 'SAC 9965 Visakhapatnam, ANDHRA PRADESH', 'Pin code: 530013, State Code: 37', 'IRN 96860529c5ba835a2389013c29822', '805b31ca3047d4f2a61196e46e9d8', '5cb815', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 10.5/Kg', 'Rs. 546.40', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 187.20', 'Markup: Rs. 1750.00', 'Taxable Amount: Rs. 2483.60', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 298.03', 'Description of charges: As per agreed terms, Total Amount Rs. 2781.63', 'In words | Two thousand, seven hundred eighty-one Rupees and sixty-three Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# ANDHRA PRADESH
# FODE23241718034
# 09-MAY-2023
# 1750.00
# 2483.60
# 298.03
# 2781.63
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply WEST BENGAL Ship To', 'Invoice No. FODE23241733220 PAPPU YADAV,S/O PAPPU YADAV', 'UDHAM SINGH SARANI ASHRAM PARA, WARD NO-1', 'Invoice Date 11-MAY-2023', '3 SILIGURI, DARJEELING W.B -734001 PH -926464505', 'SAC 9965 4', 'Siliguri, WEST BENGAL', 'IRN 32b10974ce06c7d006389ee2ce903', 'Pin code: 734001, State Code: 19', '14db8e0b91f2aefab328c31f3de7e', '965142', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 11.5/Kg', 'Rs. 1219.25', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 243.27', 'Markup: Rs. 1950.00', 'Taxable Amount: Rs. 3412.52', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 409.50', 'Description of charges: As per agreed terms, Total Amount Rs. 3822.02', 'In words | Three thousand, eight hundred twenty-two Rupees and two Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# WEST BENGAL
# FODE23241733220
# 11-MAY-2023
# 1950.00
# 3412.52
# 409.50
# 3822.02
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply CHHATISHGARH Ship To', 'Invoice No. FODE23241737310 S/O MANARAKHAN AHIR,DADU RAM AHIR', 'DUKAN NO - 03, SWAMI VIVEKANAND, DURG DURG ,', 'Invoice Date 08-MAY-2023', 'CHHATTISGARH', 'SAC 9965 Durg, CHHATISHGARH', 'Pin code: 491001, State Code: 22', 'IRN c53483b8e00a37591006c949b8728', '91bd9537c80871bd2b5c5e6819ea', '196d1f7', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 2873.79', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'ODA Charges: 4/Kg Rs. 973.26', 'Other Handling Charges: Rs. 478.48', 'Markup: Rs. 4590.00', 'Taxable Amount: Rs. 8915.53', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 1069.86', 'Description of charges: As per agreed terms, Total Amount Rs. 9985.39', 'In words | Nine thousand, nine hundred eighty-five Rupees and thirty-nine Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# CHHATISHGARH
# FODE23241737310
# 08-MAY-2023
# 4590.00
# 8915.53
# 1069.86
# 9985.39
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply JHARKHAND Ship To', 'Invoice No. FODE23241753427 HINDUSTAN UNILEVER LTD,SUDEEP', 'RANCHI DEPOT M/S SAJJAN KUMAR SARAF, NARAYA', 'Invoice Date 08-MAY-2023', 'NI COMPOUND, ACHAR FACTORY, SIDRAUL, NAMKU', 'SAC 9965 M, RANCHI, JHARKHAND-834010', 'Ranchi, JHARKHAND', 'IRN 8f857ee1f08dbe09f2bea734e2cb8', 'Pin code: 834010, State Code: 20', '6bfa0b4ec42c07e6b2ca9c7d2d0b', 'ddf2c5b', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 11.5/Kg', 'Rs. 1576.60', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 273.05', 'Markup: Rs. 650.00', 'Taxable Amount: Rs. 2499.65', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 299.96', 'Description of charges: As per agreed terms, Total Amount Rs. 2799.61', 'In words | Two thousand, seven hundred ninety-nine Rupees and sixty-one Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# JHARKHAND
# FODE23241753427
# 08-MAY-2023
# 650.00
# 2499.65
# 299.96
# 2799.61
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply HIMACHAL PRADESH Ship To', 'Invoice No. FODE23241837650 SHITLA PAPERS ,RAJESH PARMAR', 'SHITLA PAPERS PRIVATE LIMITED ROOM NO.3, 2ND', 'Invoice Date 12-MAY-2023', 'FLOOR KESHAV COMPLEX PINJORE ROAD BADDI, Hi', 'SAC 9965 machal Pradesh-173205', 'Baddi, HIMACHAL PRADESH', 'IRN 916731f80a871f2255b65a5ca749d', 'Pin code: 173205, State Code: 02', 'bc322e88796bb97ae76fa9cd86148', 'a374b5', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 7.5/Kg', 'Rs. 2365.35', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 338.78', 'Markup: Rs. 1650.00', 'Taxable Amount: Rs. 4354.13', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 522.50', 'Description of charges: As per agreed terms, Total Amount Rs. 4876.63', 'In words | Four thousand, eight hundred seventy-six Rupees and sixty-three Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# HIMACHAL PRADESH
# FODE23241837650
# 12-MAY-2023
# 1650.00
# 4354.13
# 522.50
# 4876.63
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply WEST BENGAL Ship To', 'Invoice No. FODE23241882289 HINDUSTAN UNILEVER LTD,SOUVIK MONDAL', 'HINDUSTAN UNILEVER LTD C/O, HADA TEXTILES IND', 'Invoice Date 15-MAY-2023', 'USTRIES LTD DIAMOND HARBOUR ROAD, VILL- BISH', 'SAC 9965 NUPUR, PO. & PS.- BISHNUPUR, DIST.- SOUTH 24 PA', 'RGANAS, KOLKATA-743503', 'IRN a7d6c03cd8192cad48e49a276e08 Fatepur, WEST BENGAL', '371a202ca4468b18754e906918e55', 'Pin code: 743503, State Code: 19', '0bb64bf', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 12.5/Kg', 'Rs. 6550.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'ODA Charges: 4/Kg Rs. 1720.00', 'Other Handling Charges: Rs. 859.50', 'Markup: Rs. 2370.00', 'Taxable Amount: Rs. 11499.50', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 1379.94', 'Description of charges: As per agreed terms, Total Amount Rs. 12879.44', 'In words | Twelve thousand, eight hundred seventy-nine Rupees and forty-four Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# WEST BENGAL
# FODE23241882289
# 15-MAY-2023
# 2370.00
# 11499.50
# 1379.94
# 12879.44
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'I FLOOR, 82, SECTOR-44 faridabad', 'Faridabad, HARYANA', 'Gurgaon, HARYANA', 'Pin code: 121005, State Code: 06', 'Pin code: 122002, State Code: 06', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 06AAPCS9575E1ZR', 'PAN : NA', 'Place of Supply MADHYA PRADESH Ship To', 'Invoice No. FODE23241883307 SNS INFRACOM PVT LTD,RAKESH KR, SHARMA', 'RLBCAU, VATERINARY COLLEGE,', 'Invoice Date 17-MAY-2023', 'Datia, MADHYA PRADESH', 'SAC 9965 Pin code: 475661, State Code: 23', 'IRN df25409a2a16c4f17ced1fb725f3b6', '7ee6a1db09dfb8f7a2823b0c7b74', 'dcb3bb', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 499.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'ODA Charges: 4/Kg Rs. 750.00', 'Other Handling Charges: Rs. 258.25', 'Markup: Rs. 1150.00', 'Taxable Amount: Rs. 2657.25', 'Minimum Charged Freight: 300.00/LR', 'CGST: 6.00% Rs. 159.44', 'SGST: 6.00% Rs. 159.44', 'Description of charges: As per agreed terms, Total Amount Rs. 2976.12', 'In words | Two thousand, nine hundred seventy-six Rupees and twelve Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E']
# MADHYA PRADESH
# FODE23241883307
# 17-MAY-2023
# 1150.00
# 2657.25
# 159.44
# 159.44
# 2976.12
# GLOBAL
# ['This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply KARNATAKA Ship To', 'Invoice No. FODE23241963696 DALPAT RAJ ,S,O SONA RAM', 'VIVEK NAGAR, NEAR POST OFFICE BENGALURU', 'Invoice Date 20-MAY-2023', 'Bangalore, KARNATAKA', 'SAC 9965 Pin code: 560047, State Code: 29', 'IRN e3024b1b4b7f7681edcdda02213e', 'cfe2de50d0d7208c22eae70224923', 'ef671df', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 2873.79', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 381.15', 'Markup: Rs. 3850.00', 'Taxable Amount: Rs. 7104.94', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 852.59', 'Description of charges: As per agreed terms, Total Amount Rs. 7957.53', 'In words | Seven thousand, nine hundred fifty-seven Rupees and fifty-three Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# KARNATAKA
# FODE23241963696
# 20-MAY-2023
# 3850.00
# 7104.94
# 852.59
# 7957.53
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply MADHYA PRADESH Ship To', 'Invoice No. FODE23241980076 AMBICA AUTO PARTS,AMBIKA', '43, GAUSHALA ROAD, OPP AXIS BANK, JAORA, DISST', 'Invoice Date 23-MAY-2023', 'RATLAM', 'SAC 9965 Jaora, MADHYA PRADESH', 'Pin code: 457226, State Code: 23', 'IRN f46029356b731a03668e6b2d6728f', '81cb41392364ecbb326149e860399', '438fba', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 616.36', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'ODA Charges: 4/Kg Rs. 750.00', 'Other Handling Charges: Rs. 268.03', 'Markup: Rs. 500.00', 'Taxable Amount: Rs. 2134.39', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 256.13', 'Description of charges: As per agreed terms, Total Amount Rs. 2390.52', 'In words | Two thousand, three hundred ninety Rupees and fifty-two Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# MADHYA PRADESH
# FODE23241980076
# 23-MAY-2023
# 500.00
# 2134.39
# 256.13
# 2390.52
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', '249 2, GIDC ROAD NO 2, OPP MINAXI DYENING, SACHIN faridabad', 'Faridabad, HARYANA', 'Surat, GUJARAT', 'Pin code: 121005, State Code: 06', 'Pin code: 394230, State Code: 24', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 24AAPCS9575E1ZT', 'PAN : NA', 'Place of Supply UTTAR PRADESH Ship To', 'Invoice No. FODE23242027065 HABIB TALIB ,TALIB', 'HABIB TALIB -B 18/52 R REORI TALAB, VARANASI, NE', 'Invoice Date 22-MAY-2023', 'AR QADIRYA MASJID, VARANASI- 221001', 'SAC 9965 Varanasi, UTTAR PRADESH', 'Pin code: 221001, State Code: 09', 'IRN c5eb9e3b21ebba76f0ffda5871f1b', '7c3642ad022d14e04b94ee4991e8', '2f577f7', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 10.5/Kg', 'Rs. 1423.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 260.25', 'Markup: Rs. 650.00', 'Taxable Amount: Rs. 2333.25', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 279.99', 'Description of charges: As per agreed terms, Total Amount Rs. 2613.24', 'In words | Two thousand, six hundred thirteen Rupees and twenty-four Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# UTTAR PRADESH
# FODE23242027065
# 22-MAY-2023
# 650.00
# 2333.25
# 279.99
# 2613.24
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply TAMILNADU Ship To', 'Invoice No. FODE23242043388 RAM DAYAL,RAM DAYAL', 'S/O JEEWAN RAM. 17 ROBINSON NAGAR MADANAK', 'Invoice Date 25-MAY-2023', 'UPPAM, KOLATHUR TIRU VALLUR', 'SAC 9965 Chennai, TAMILNADU', 'Pin code: 600099, State Code: 33', 'IRN d963848019111c2804afcce658f6a', 'b30d0202130129eee6612a75548cf', 'b314f4', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 1949.20', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 304.10', 'Markup: Rs. 3950.00', 'Taxable Amount: Rs. 6203.30', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 744.40', 'Description of charges: As per agreed terms, Total Amount Rs. 6947.70', 'In words | Six thousand, nine hundred forty-seven Rupees and seventy Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# TAMILNADU
# FODE23242043388
# 25-MAY-2023
# 3950.00
# 6203.30
# 744.40
# 6947.70
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply WEST BENGAL Ship To', 'Invoice No. FODE23242047364 HINDUSTAN UNILEVER LTD,SOUVIK MONDAL', 'C/O, HADA TEXTILES INDUSTRIES LTD DIAMOND HA', 'Invoice Date 23-MAY-2023', 'RBOUR ROAD, VILL- BISHNUPUR, PO. & PS.- BISHN', 'SAC 9965 UPUR, DIST.- SOUTH 24 PARGANAS, KOLKATA-74350', '3 CONTACT PERSON: MR. SOUVIK MONDAL CONTA', 'IRN 0eef71581533634ebaae2c6b76f55 CT NO.: 7605838580', '3b8095864204829745d51253882d7 Fatepur, WEST BENGAL', 'a8e7dc', 'Pin code: 743503, State Code: 19', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 12.5/Kg', 'Rs. 10255.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'ODA Charges: 4/Kg Rs. 2708.00', 'Other Handling Charges: Rs. 1267.05', 'Markup: Rs. 3600.00', 'Taxable Amount: Rs. 17830.05', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 2139.61', 'Description of charges: As per agreed terms, Total Amount Rs. 19969.66', 'In words | Nineteen thousand, nine hundred sixty-nine Rupees and sixty-six Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# WEST BENGAL
# FODE23242047364
# 23-MAY-2023
# 3600.00
# 17830.05
# 2139.61
# 19969.66
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply GOA Ship To', 'Invoice No. FODE23242143094 CALTEX,CALTEX', 'CALTEX 24 VOGUE Store, Shree Nichaldas Arcade Bui', 'Invoice Date 30-MAY-2023', 'lding, Groud Floor Shop No-11, Candolim Beach Ro', 'SAC 9965 ad, Gaurawaddo Calangute Bardez North Goa-40351', '6 Contact No. : 9322284212', 'IRN fab50707753d2fdb1057345d9c82e Goa, GOA', 'f0470bde53fdbdea84f1ab9ac5cca', 'Pin code: 403516, State Code: 30', '13c83e', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9.5/Kg', 'Rs. 563.82', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'ODA Charges: 4/Kg Rs. 750.00', 'Other Handling Charges: Rs. 263.65', 'Markup: Rs. 1500.00', 'Taxable Amount: Rs. 3077.47', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 369.30', 'Description of charges: As per agreed terms, Total Amount Rs. 3446.77', 'In words | Three thousand, four hundred forty-six Rupees and seventy-seven Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# GOA
# FODE23242143094
# 30-MAY-2023
# 1500.00
# 3077.47
# 369.30
# 3446.77
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi faridabad', 'Faridabad, HARYANA', 'Delhi, DELHI', 'Pin code: 121005, State Code: 06', 'Pin code: 110075, State Code: 07', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 07AAPCS9575E1ZP', 'PAN : NA', 'Place of Supply ANDHRA PRADESH Ship To', 'Invoice No. FODE23242184045 INDISO TRENDS LLP,HARI GAARU', 'INDISO TRENDS, CMR CENTRAL PARKING AREA , MA', 'Invoice Date 31-MAY-2023', 'DDILAPALEM , VISAKHAPATNAM-530013', 'SAC 9965 Visakhapatnam, ANDHRA PRADESH', 'Pin code: 530013, State Code: 37', 'IRN ee25f5be2c64fa4254e7f2425d2e3', '8637f0862036bbb28867a5b14f301', 'e0ed5d', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 10.5/Kg', 'Rs. 415.00', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 176.25', 'Markup: Rs. 1600.00', 'Taxable Amount: Rs. 2191.25', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 262.95', 'Description of charges: As per agreed terms, Total Amount Rs. 2454.20', 'In words | Two thousand, four hundred fifty-four Rupees and twenty Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# ANDHRA PRADESH
# FODE23242184045
# 31-MAY-2023
# 1600.00
# 2191.25
# 262.95
# 2454.20
# GLOBAL
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL , GLOBAL', '249 2, GIDC ROAD NO 2, OPP MINAXI DYENING, SACHIN faridabad', 'Faridabad, HARYANA', 'Surat, GUJARAT', 'Pin code: 121005, State Code: 06', 'Pin code: 394230, State Code: 24', 'GSTIN : 06AEYPR6542L2ZJ', 'GSTIN : 24AAPCS9575E1ZT', 'PAN : NA', 'Place of Supply TAMILNADU Ship To', 'Invoice No. FODE23242199175 KOVAI BEAUTY COSMATICS,KOVAI', 'KOVAI BEAUTY COSMETICS No.103,, 3rd STREET, GA', 'Invoice Date 31-MAY-2023', 'NDHIPURAM COIMBATORE, Coimbatore Tamil Nadu', 'SAC 9965 PIN -641012 PH 9994689186', 'Coimbatore, TAMILNADU', 'IRN 1a138455eb8454593df599eab7a01', 'Pin code: 641012, State Code: 33', '17dae089be0b8c8a88c32adcb6c6', '009f7ff', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 8.5/Kg', 'Rs. 4255.97', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Other Handling Charges: Rs. 496.33', 'Markup: Rs. 1000.00', 'Taxable Amount: Rs. 5752.30', 'Minimum Charged Freight: 300.00/LR', 'IGST: 12.00% Rs. 690.28', 'Description of charges: As per agreed terms, Total Amount Rs. 6442.58', 'In words | Six thousand, four hundred forty-two Rupees and fifty-eight Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# TAMILNADU
# FODE23242199175
# 31-MAY-2023
# 1000.00
# 5752.30
# 690.28
# 6442.58
# GLOBAL
# ...
# GUJARAT
# FODL23252911139
# 13-DEC-2023
# 1850.00
# 5571.99
# 668.64
# 6240.63
# GLOBAL SERVI
# ['This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL SERVICES , GLOBAL SERVI', 'CES', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi', 'Delhi, DELHI IH-24A NIT FARIDABAD', 'Faridabad, HARYANA', 'Pin code: 110075, State Code: 07', 'Pin code: 121005, State Code: 06', 'GSTIN : 07AAPCS9575E1ZP', 'GSTIN : 06AEYPR6542L2ZJ', 'PAN : NA', 'Place of Supply GUJARAT Ship To', 'Invoice No. FODL23252953335 SAVLE BALAJI ,SAVLE BALAJI', 'SAVLE BALAJI ASMRUJI 1/1511 A FLAT NO 301 MEGA', 'Invoice Date 16-DEC-2023', 'PALACE GODHA MAHOLLO KADARSHA NI NAL NAN', 'SAC 9965 PURA SUNVALI SURAT NAN PURA GUJARA 395001 Su', 'rat , Gujarat', 'IRN c46dfab53c45f160aa76460d1a5b8 Surat, GUJARAT', '7cfc36b885c95390ac3ccc4718d74', 'Pin code: 395001, State Code: 24', '62d712', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 8/Kg', 'Rs. 3774.92', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.05% Rs. 50.00', 'FM Charges: 1/Kg Rs. 382.80', 'Other Handling Charges: Rs. 100.00', 'Markup: Rs. 1800.00', 'Taxable Amount: Rs. 6107.72', 'Minimum Charged Freight: 350.00/LR', 'IGST: 12.00% Rs. 732.93', 'Description of charges: As per agreed terms, Total Amount Rs. 6840.65', 'In words | Six thousand, eight hundred forty Rupees and sixty-five Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E']
# GUJARAT
# FODL23252953335
# 16-DEC-2023
# 1800.00
# 6107.72
# 732.93
# 6840.65
# GLOBAL SERVI
# ['This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL SERVICES , GLOBAL SERVI', 'CES', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi', 'Delhi, DELHI IH-24A NIT FARIDABAD', 'Faridabad, HARYANA', 'Pin code: 110075, State Code: 07', 'Pin code: 121005, State Code: 06', 'GSTIN : 07AAPCS9575E1ZP', 'GSTIN : 06AEYPR6542L2ZJ', 'PAN : NA', 'Place of Supply GUJARAT Ship To', 'Invoice No. FODL23252997528 SAVLE BALAJI ,SAVLE BALAJI', 'SAVLE BALAJI ,SAVLE BALAJISAVLE BALAJI ASMRUJI 1/', 'Invoice Date 18-DEC-2023', '1511 A FLAT NO 301 MEGA PALACE GODHA MAHOL', 'SAC 9965 LO KADARSHA NI NAL NAN PURA SUNVALI SURAT N', 'AN PURA GUJARA 395001 Surat , Gujarat, Surat, 3950', 'IRN 6d79b4760262f73b85b32f2f78fccf6 01.', '7b5ba0526c72f3fcf41dfd225fb616 Surat, GUJARAT', 'd14', 'Pin code: 395001, State Code: 24', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 8/Kg', 'Rs. 624.95', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.05% Rs. 50.00', 'FM Charges: 1/Kg Rs. 54.68', 'Other Handling Charges: Rs. 100.00', 'Markup: Rs. 650.00', 'Taxable Amount: Rs. 1479.63', 'Minimum Charged Freight: 350.00/LR', 'IGST: 12.00% Rs. 177.56', 'Description of charges: As per agreed terms, Total Amount Rs. 1657.19', 'In words | One thousand, six hundred fifty-seven Rupees and nineteen Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E']
# GUJARAT
# FODL23252997528
# 18-DEC-2023
# 650.00
# 1479.63
# 177.56
# 1657.19
# GLOBAL SERVI
# ['This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL SERVICES , GLOBAL SERVI', 'CES', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi', 'Delhi, DELHI IH-24A NIT FARIDABAD', 'Faridabad, HARYANA', 'Pin code: 110075, State Code: 07', 'Pin code: 121005, State Code: 06', 'GSTIN : 07AAPCS9575E1ZP', 'GSTIN : 06AEYPR6542L2ZJ', 'PAN : NA', 'Place of Supply KERALA Ship To', 'Invoice No. FODL23253052039 DANISH,DANISH', 'DANISH ANTONY MARATHOMTHARA KOTTUVALLY K', 'Invoice Date 21-DEC-2023', 'AITHARAM PO KAITHARAM SO KAITHARAM ERNAKU', 'SAC 9965 LAM KERALA 683519 PH =9072408601', 'North Paravur, KERALA', 'IRN 58232cb701b2471abf4416a95ce31', 'Pin code: 683519, State Code: 32', 'b94c8645e04a7681f5e9da043eb20', '7780f9', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 10.8/Kg', 'Rs. 6614.04', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.05% Rs. 50.00', 'ODA Charges: 3/Kg Rs. 1507.88', 'FM Charges: 1/Kg Rs. 502.63', 'Other Handling Charges: Rs. 100.00', 'Markup: Rs. 3500.00', 'Taxable Amount: Rs. 12274.55', 'Minimum Charged Freight: 350.00/LR', 'IGST: 12.00% Rs. 1472.95', 'Description of charges: As per agreed terms, Total Amount Rs. 13747.50', 'In words | Thirteen thousand, seven hundred forty-seven Rupees and fifty Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India']
# KERALA
# FODL23253052039
# 21-DEC-2023
# 3500.00
# 12274.55
# 1472.95
# 13747.50
# GLOBAL SERVI
# ['Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL SERVICES , GLOBAL SERVI', 'CES', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi', 'Delhi, DELHI IH-24A NIT FARIDABAD', 'Faridabad, HARYANA', 'Pin code: 110075, State Code: 07', 'Pin code: 121005, State Code: 06', 'GSTIN : 07AAPCS9575E1ZP', 'GSTIN : 06AEYPR6542L2ZJ', 'PAN : NA', 'Place of Supply KERALA Ship To', 'Invoice No. FODL23253081294 TONY,TONY', 'TONY MANJOORAN KAITHARAM PO PARAVUR KAI T', 'Invoice Date 28-DEC-2023', 'HARAM SO ERNAKULAM KERALA 683519', 'SAC 9965 North Paravur, KERALA', 'Pin code: 683519, State Code: 32', 'IRN 5ebc3b32feed4c58eb601473e88c', '8dab1974afa1c8f6d9f7abf317d41', '6863213', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 10.8/Kg', 'Rs. 2997.70', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.05% Rs. 50.00', 'ODA Charges: 3/Kg Rs. 670.76', 'FM Charges: 1/Kg Rs. 223.59', 'Other Handling Charges: Rs. 100.00', 'Markup: Rs. 2000.00', 'Taxable Amount: Rs. 6042.05', 'Minimum Charged Freight: 350.00/LR', 'IGST: 12.00% Rs. 725.05', 'Description of charges: As per agreed terms, Total Amount Rs. 6767.10', 'In words | Six thousand, seven hundred sixty-seven Rupees and ten Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India']
# KERALA
# FODL23253081294
# 28-DEC-2023
# 2000.00
# 6042.05
# 725.05
# 6767.10
# GLOBAL SERVI
# ['Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E', 'This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL SERVICES , GLOBAL SERVI', 'CES', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi', 'Delhi, DELHI IH-24A NIT FARIDABAD', 'Faridabad, HARYANA', 'Pin code: 110075, State Code: 07', 'Pin code: 121005, State Code: 06', 'GSTIN : 07AAPCS9575E1ZP', 'GSTIN : 06AEYPR6542L2ZJ', 'PAN : NA', 'Place of Supply GUJARAT Ship To', 'Invoice No. FODL23253161999 VAISHNAV LALIT KUMAR ,VAISHNAV LALIT', 'VAISHNAV LALIT KUMAR CHOTADOS 201 KRISHAN A', 'Invoice Date 27-DEC-2023', 'ARON SARDAR PETAL RAJ MARG ANAND ANAND GUJ', 'SAC 9965 AROT 388001', 'Anand, GUJARAT', 'IRN ff66802a5708cf89e03d54b36bbab', 'Pin code: 388001, State Code: 24', 'b4acccc1a1ed4ff1772ddb9028804', '2ac727', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 8/Kg', 'Rs. 2388.94', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.05% Rs. 50.00', 'FM Charges: 1/Kg Rs. 238.43', 'Other Handling Charges: Rs. 100.00', 'Markup: Rs. 2000.00', 'Taxable Amount: Rs. 4777.37', 'Minimum Charged Freight: 350.00/LR', 'IGST: 12.00% Rs. 573.28', 'Description of charges: As per agreed terms, Total Amount Rs. 5350.65', 'In words | Five thousand, three hundred fifty Rupees and sixty-five Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E']
# GUJARAT
# FODL23253161999
# 27-DEC-2023
# 2000.00
# 4777.37
# 573.28
# 5350.65
# GLOBAL SERVI
# ['This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL SERVICES , GLOBAL SERVI', 'CES', 'plot no. 338, Village Bhartal, Sector 26, South West Delhi', 'Delhi, DELHI IH-24A NIT FARIDABAD', 'Faridabad, HARYANA', 'Pin code: 110075, State Code: 07', 'Pin code: 121005, State Code: 06', 'GSTIN : 07AAPCS9575E1ZP', 'GSTIN : 06AEYPR6542L2ZJ', 'PAN : NA', 'Place of Supply GOA Ship To', 'Invoice No. FODL23253162699 SONALI SATYAJIT,SONALI SATYAJIT', 'SONALI SATYAJIT PRABAUDESSSAI, HOUSE NO. 48/2,', 'Invoice Date 26-DEC-2023', 'GF-81,COMFORT COLONY WARD NO 8, (OPP) DOVO', 'SAC 9965 R LIM MOSQUE LEYAMATI DOVORLIM NAVELIM SAL', 'CETE GOA', 'IRN 044a68ea49dab6a37798f9540e105 Goa, GOA', 'ab7cb2ffeea9bc7591f9eb60cc987', 'Pin code: 403707, State Code: 30', 'd7b7a7', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 9/Kg', 'Rs. 943.35', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.05% Rs. 50.00', 'FM Charges: 1/Kg Rs. 78.09', 'Other Handling Charges: Rs. 100.00', 'Markup: Rs. 2750.00', 'Taxable Amount: Rs. 3921.44', 'Minimum Charged Freight: 350.00/LR', 'IGST: 12.00% Rs. 470.57', 'Description of charges: As per agreed terms, Total Amount Rs. 4392.01', 'In words | Four thousand, three hundred ninety-two Rupees and one Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E']
# GOA
# FODL23253162699
# 26-DEC-2023
# 2750.00
# 3921.44
# 470.57
# 4392.01
# GLOBAL SERVI
# ['This is a system generated invoice. It does not require additional authorization.']
# error
# ['TAX INVOICE', 'Small World', 'From Bill To', 'DELHIVERY LIMITED GLOBAL SERVICES , GLOBAL SERVI', 'CES', 'GIDANKHERA NADARGANJ, AMOUSI', 'Lucknow, UTTAR PRADESH IH-24A NIT FARIDABAD', 'Faridabad, HARYANA', 'Pin code: 226008, State Code: 09', 'Pin code: 121005, State Code: 06', 'GSTIN : 09AAPCS9575E1ZL', 'GSTIN : 06AEYPR6542L2ZJ', 'PAN : NA', 'Place of Supply TAMILNADU Ship To', 'Invoice No. FODL23253165684 SMAAASH ENTERTAINMENT ,SMAAASH ENTERTAI', 'NMENT', 'Invoice Date 27-DEC-2023', 'Smaaash Entertainment Pvt Ltd 4TH FLOOR, VISHAL', 'SAC 9965 DE MALL, CHINNA CHOKKIKULAM, GOKHALE ROAD,', 'MADURAI, MADURAI, TAMIL NADU, 625002 Contact-', 'IRN 62d5bba798cb7f6d3a605de61231 9080995511', '12d0057c8307bd87a627c8cd9d1f6 Madurai, TAMILNADU', 'c121362', 'Pin code: 625002, State Code: 33', 'Description Units Invoice Amount', 'Base Freight Charge', 'Base Charge: 10.8/Kg', 'Rs. 1061.12', 'Processing Charge: 100.00/LR', 'Fuel Charges: 20%', 'Insurance ROV: 0.05% Rs. 50.00', 'FM Charges: 1/Kg Rs. 74.16', 'Other Handling Charges: Rs. 100.00', 'Markup: Rs. 800.00', 'Taxable Amount: Rs. 2085.28', 'Minimum Charged Freight: 350.00/LR', 'IGST: 12.00% Rs. 250.23', 'Description of charges: As per agreed terms, Total Amount Rs. 2335.51', 'In words | Two thousand, three hundred thirty-five Rupees and fifty-one Paisa only', 'Terms and Conditions', '1. All payments to be made only through Account Payee Cheque/DD/RTGS in favor of Delhivery Limited.', '2. Interest @ 2.00% per month or part thereof will be charged if the bill is not paid on due date.', '3. All disputes and differences arising out of this will be subject to jurisdiction of Gurgaon courts only.', 'DELHIVERY LIMITED', 'Registered Office: N24-N34, S24-S34, Air Cargo Logistics Centre-II, Opposite Gate 6 Cargo Terminal, IGI Airport, New Delhi - 110037,', 'India', 'Tel: +91 124 6719500, Email: info@delhivery.com, Web: www.delhivery.com', 'Delhi GST No.: 07AAPCS9575E1ZP, CIN: L63090DL2011PLC221234, PAN: AAPCS9575E']
# TAMILNADU
# FODL23253165684
# 27-DEC-2023
# 800.00
# 2085.28
# 250.23
# 2335.51
# GLOBAL SERVI
# ['This is a system generated invoice. It does not require additional authorization.']
# error

# %%
# %pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl.metadata (2.6 kB)
# Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.9
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df.to_excel('Bill_excel.xlsx', sheet_name='bills', index=False, engine='xlsxwriter')
